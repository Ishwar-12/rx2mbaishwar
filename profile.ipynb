# %%
class Person:
    def __init__(self, name, contact, email, location, linkedin):
        self.name = name
        self.contact = contact
        self.email = email
        self.location = location
        self.linkedin = linkedin

class Education:
    def __init__(self, degree, institution, university, year, result):
        self.degree = degree
        self.institution = institution
        self.university = university
        self.year = year
        self.result = result

class Experience:
    def __init__(self, title, organization, duration, responsibilities):
        self.title = title
        self.organization = organization
        self.duration = duration
        self.responsibilities = responsibilities

class Project:
    def __init__(self, title, description):
        self.title = title
        self.description = description

class Resume:
    def __init__(self, personal_info, education, experience, projects, certifications, skills, personal_details):
        self.personal_info = personal_info
        self.education = education
        self.experience = experience
        self.projects = projects
        self.certifications = certifications
        self.skills = skills
        self.personal_details = personal_details

# Personal Info
personal_info = Person(
    name="Ishwar B Wagh",
    contact="+91 9168738155",
    email="iwagh550@gmail.com",
    location="Aurangabad, Maharashtra",
    linkedin="https://www.linkedin.com/in/ishwar-wagh-8721b11aa"
)

# Education
education = [
    Education("MBA (Hospital Administration)", "International Centre of Excellence in Engineering and Management", "Dr. Babasaheb Ambedkar Marathwada University", "Result Awaited", "Awaiting Results"),
    Education("Bachelor of Pharmacy", "SSJP’s Shree Sai College of Pharmacy, Vaijapur", "Dr. Babasaheb Ambedkar Technological University", "Sept 2022", "7.93 CGPA"),
    Education("HSC (12th)", "New High School, Chauka", "Maharashtra State Board", "Feb 2018", "65.23%"),
    Education("SSC (10th)", "Mount Valley English School, Aurangabad", "Maharashtra State Board", "March 2016", "77.20%")
]

# Experience
experience = Experience(
    title="Assistant Pharmacist",
    organization="Panchashil Medical Stores (Hedgewar Hospital Sanchalit)",
    duration="December 4, 2023 – September 27, 2024",
    responsibilities=[
        "Dispensed medications as per prescriptions with accuracy.",
        "Maintained inventory and medication storage standards.",
        "Interacted with patients to provide dosage instructions.",
        "Supported healthcare team in pharmacy operations."
    ]
)

# Projects
projects = [
    Project("Formulation of Herbal Face Pack", "Developed a skin-friendly face pack using herbal ingredients."),
    Project("Zinc-Oxide Ointment", "Formulated and evaluated ointment for minor skin irritations.")
]

# Certifications
certifications = [
    "Microsoft Office",
    "Diploma in Healthcare Administration, Management & Leadership"
]

# Skills
skills = [
    "Microsoft Office Suite",
    "Computer Handling",
    "Documentation & Report Writing",
    "Basic Pharmacy Formulation Knowledge"
]

# Personal Details
personal_details = {
    "Date of Birth": "12 October 1998",
    "Marital Status": "Unmarried",
    "Nationality": "Indian",
    "Languages Known": ["English", "Hindi", "Marathi"],
    "Hobbies": ["Listening to music", "Playing cricket", "Drawing", "Sketching"]
}

# Final Resume Object
ishwar_resume = Resume(
    personal_info=personal_info,
    education=education,
    experience=experience,
    projects=projects,
    certifications=certifications,
    skills=skills,
    personal_details=personal_details
)
